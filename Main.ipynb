# %%
# %load_ext autoreload
# %autoreload 2

# %%
from Prediction_Models import predict_ARIMA, predict_HW, predict_ARIMA_MAPE, predict_HW_MAPE
from Dataprep import Adjust_DataSet
import datetime
import pandas as pd
import numpy as np

# %% [markdown]
# # Read Input

# %%
Branch_revenue = pd.read_csv("Data/Data Row/Branch_Revenue.csv")
items_dfs = {}
for i in range(1,19):
    items_dfs[f"item_{i}"] = pd.read_csv(f"Data/Data Row/item_{i}.csv")

# %% [markdown]
# # SARIMA Model forcasting Jan, Feb and March

# %% [markdown]
# ## Daily

# %%
for i in range(1,19):
    df = items_dfs[f"item_{i}"]
    df_ = Adjust_DataSet(df,"D","quantity")
    test_days = 90
    training_df = df_.iloc[:,:]
    prediction_df = pd.DataFrame(np.nan, index = pd.date_range(datetime.datetime(2022,1,1), datetime.datetime(2022,1,1)+datetime.timedelta(90),freq='D'), columns = ['quantity'])
    predict_ARIMA(f"item_{i}",training_df,prediction_df,"quantity","Daily")

# %% [markdown]
# ## Weekly

# %%
for i in range(1,19):
    try:
        df = pd.read_csv(f"Data/Data Row/item_{i}.csv")
        df_ = Adjust_DataSet(df,"W","quantity")
        test_weeks = 12
        training_df = df_.iloc[:,:]
        prediction_df = pd.DataFrame(np.nan, index = pd.date_range(datetime.datetime(2022,1,1), datetime.datetime(2022,1,1)+datetime.timedelta(90),freq='W'), columns = ['quantity'])
        predict_ARIMA(f"item_{i}",training_df,prediction_df,"quantity","Weekly")
    except:
        pass

# %% [markdown]
# ## Monthly

# %%
for i in range(1,19):
    df = pd.read_csv(f"Data/Data Row/item_{i}.csv")
    df_ = Adjust_DataSet(df,"M","quantity")
    test_months = 3
    training_df = df_.iloc[:,:]
    prediction_df = pd.DataFrame(np.nan, index = pd.date_range(datetime.datetime(2022,1,1), datetime.datetime(2022,1,1)+datetime.timedelta(90),freq='M'), columns = ['quantity'])
    predict_ARIMA(f"item_{i}",training_df,prediction_df,"quantity","Monthly")
# Out:
# /home/omar.abdelkarim/.local/lib/python3.10/site-packages/pmdarima/arima/_auto_solvers.py:522: ModelFitWarning: Error fitting  ARIMA(1,0,3)(0,0,0)[1] intercept (if you do not want to see these warnings, run with error_action="ignore").
# Traceback:
# Traceback (most recent call last):
#   File "/home/omar.abdelkarim/.local/lib/python3.10/site-packages/pmdarima/arima/_auto_solvers.py", line 506, in _fit_candidate_model
#     fit.fit(y, X=X, **fit_params)
#   File "/home/omar.abdelkarim/.local/lib/python3.10/site-packages/pmdarima/arima/arima.py", line 603, in fit
#     self._fit(y, X, **fit_args)
#   File "/home/omar.abdelkarim/.local/lib/python3.10/site-packages/pmdarima/arima/arima.py", line 524, in _fit
#     fit, self.arima_res_ = _fit_wrapper()
#   File "/home/omar.abdelkarim/.local/lib/python3.10/site-packages/pmdarima/arima/arima.py", line 510, in _fit_wrapper
#     fitted = arima.fit(
# ...

# %% [markdown]
# ## Branch Jan

# %%
df = pd.read_csv(f"Data/Data Row/Branch_Revenue.csv")
df_ = Adjust_DataSet(df,"D","revenue")
test_size = 31
training_df = df_.iloc[:,:]
prediction_df = pd.DataFrame(np.nan, index = pd.date_range(datetime.datetime(2022,1,1), datetime.datetime(2022,1,1)+datetime.timedelta(90),freq='D'), columns = ['quantity'])
predict_ARIMA(f"Branch_Revenue",training_df,prediction_df,"revenue","Daily")
# Out:
# 2022-01-01    6343.456479
# 2022-01-02    5758.793933
# 2022-01-03    5006.897411
# 2022-01-04    4544.717755
# 2022-01-05    4629.734163
#                  ...
# 2022-03-28    4848.025895
# 2022-03-29    4589.468829
# 2022-03-30    4558.288426
# 2022-03-31    4773.811179
# 2022-04-01    5072.479356
# Freq: D, Name: SARIMA, Length: 91, dtype: float64

# %% [markdown]
# # HW Forcasting Jan, Feb and March

# %% [markdown]
# ## Daily

# %%
for i in range(1,19):
    df = items_dfs[f"item_{i}"]
    df_ = Adjust_DataSet(df,"D","quantity")
    test_days = 90
    training_df = df_.iloc[:,:]
    prediction_df = pd.DataFrame(np.nan, index = pd.date_range(datetime.datetime(2022,1,1), datetime.datetime(2022,1,1)+datetime.timedelta(90),freq='D'), columns = ['quantity'])
    predict_HW(f"item_{i}",training_df,prediction_df,"quantity","Daily")

# %% [markdown]
# ## Weekly

# %%
for i in range(1,19):
    df = items_dfs[f"item_{i}"]
    df_ = Adjust_DataSet(df,"W","quantity")
    test_size = 12
    training_df = df_.iloc[:,:]
    prediction_df = pd.DataFrame(np.nan, index = pd.date_range(datetime.datetime(2022,1,1), datetime.datetime(2022,1,1)+datetime.timedelta(90),freq='W'), columns = ['quantity'])
    predict_HW(f"item_{i}",training_df,prediction_df,"quantity","Weekly")

# %% [markdown]
# ## Monthly

# %%
for i in range(1,19):
    df = items_dfs[f"item_{i}"]
    df_ = Adjust_DataSet(df,"M","quantity")
    test_size = 3
    training_df = df_.iloc[:,:]
    prediction_df = pd.DataFrame(np.nan, index = pd.date_range(datetime.datetime(2022,1,1), datetime.datetime(2022,1,1)+datetime.timedelta(90),freq='M'), columns = ['quantity'])
    predict_HW(f"item_{i}",training_df,prediction_df,"quantity","Monthly")

# %% [markdown]
# ## Branch Jan Daily

# %%
df = pd.read_csv(f"Data/Data Row/Branch_Revenue.csv")
df_ = Adjust_DataSet(df,"D","revenue")
test_size = 31
training_df = df_.iloc[:,:]
prediction_df = pd.DataFrame(np.nan, index = pd.date_range(datetime.datetime(2022,1,1), datetime.datetime(2022,1,1)+datetime.timedelta(90),freq='D'), columns = ['quantity'])
predict_HW(f"Branch_Revenue",training_df,prediction_df,"revenue","Daily")
# Out:
# /home/omar.abdelkarim/.local/lib/python3.10/site-packages/statsmodels/tsa/holtwinters/model.py:915: ConvergenceWarning: Optimization failed to converge. Check mle_retvals.
#   warnings.warn(
# 2021-12-31     7867.332157
# 2022-01-01     6758.837854
# 2022-01-02     5374.046793
# 2022-01-03     5196.508198
# 2022-01-04     5352.113699
#                   ...
# 2022-03-27     8001.500634
# 2022-03-28     7823.962040
# 2022-03-29     7979.567540
# 2022-03-30     8787.044439
# 2022-03-31    10391.395675
# Freq: D, Name: prediction, Length: 91, dtype: float64

# %% [markdown]
# # Forecasting with MAPE Using Holt_Winters

# %% [markdown]
# ## Daily

# %%
for i in range(1,19):
    df = items_dfs[f"item_{i}"]
    df_ = Adjust_DataSet(df,"D","quantity")
    test_days = 31
    training_df = df_.iloc[:-test_days,:]
    test_df = df_.iloc[-test_days:,:]
    predict_HW_MAPE(f"item_{i}",training_df,prediction_df,"quantity","Daily")
# Out:
# /home/omar.abdelkarim/.local/lib/python3.10/site-packages/statsmodels/tsa/holtwinters/model.py:83: RuntimeWarning: overflow encountered in matmul
#   return err.T @ err
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In [37], line 7
#       5 training_df = df_.iloc[:-test_days,:]
#       6 test_df = df_.iloc[-test_days:,:]
# ----> 7 predict_HW_MAPE(f"item_{i}",training_df,prediction_df,"quantity","Daily")
#
# File ~/Desktop/CodingChallenge/Datascience/Prediction_Models.py:58, in predict_HW_MAPE(name, training_set, test_set, key, type)
#      56 predictions = model.forecast(steps= len(test_set)).rename('prediction')
#      57 predictions['actual'] = test_set[f"{key}"]
# ---> 58 predictions['MAPE'] = predictions.apply(lambda x: MAPE(x['actual'],x[f'{key}']))
#      59 plt.plot(training_set[f"{key}"])
#      60 plt.plot(predictions)
#
# ...

# %%
def MAPE(actual, prediction):
    actual, prediction = np.array(actual), np.array(prediction)
    return np.mean(np.abs((actual - prediction)/actual))* 100
from pmdarima import auto_arima
from statsmodels.tsa.holtwinters import ExponentialSmoothing
import matplotlib.pyplot as plt
key = 'quantity'
name = 'item_1'
df = items_dfs[f"item_1"]
df_ = Adjust_DataSet(df,"D","quantity")
test_days = 31
training_set = df_.iloc[:-test_days,:]
test_set = df_.iloc[-test_days:,:]
model = ExponentialSmoothing(endog = training_set[f"{key}"],trend='mul',seasonal='mul',seasonal_periods = 7).fit()
predictions = model.forecast(steps= len(test_set)).rename('prediction')
# predictions['actual'] = test_set[f"{key}"]
# predictions['MAPE'] = predictions.apply(lambda x: MAPE(x['actual'],x[f'{key}']))
# plt.plot(training_set[f"{key}"])
# plt.plot(predictions)
# plt.savefig(f"Results_MAPE/{type}/{name}_{str(test_set.index[0].date())}_{str(test_set.index[-1].date())}_HW_Predictions.png")
# plt.clf()
# predictions.to_csv(f"Results_MAPE/{type}/{name}_{str(test_set.index[0].date())}_{str(test_set.index[-1].date())}_HW_Predictions.csv")
# Out:
# /home/omar.abdelkarim/.local/lib/python3.10/site-packages/statsmodels/tsa/holtwinters/model.py:83: RuntimeWarning: overflow encountered in matmul
#   return err.T @ err
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In [39], line 17
#      15 predictions = model.forecast(steps= len(test_set)).rename('prediction')
#      16 predictions['actual'] = test_set[f"{key}"]
# ---> 17 predictions['MAPE'] = predictions.apply(lambda x: MAPE(x['actual'],x[f'{key}']))
#      18 plt.plot(training_set[f"{key}"])
#      19 plt.plot(predictions)
#
# File ~/.local/lib/python3.10/site-packages/pandas/core/series.py:4771, in Series.apply(self, func, convert_dtype, args, **kwargs)
#    4661 def apply(
#    4662     self,
#    4663     func: AggFuncType,
#    (...)
#    4666     **kwargs,
#    4667 ) -> DataFrame | Series:
#    4668     """
#    4669     Invoke function on values of Series.
# ...
